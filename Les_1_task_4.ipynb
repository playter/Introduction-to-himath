# %%
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(0, 10, 140)
k=1
plt.plot(x, np.cos(k * x))
k=3
plt.plot(x, np.cos(k * x))
